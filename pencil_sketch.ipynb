# %% [markdown]
# <a href="https://colab.research.google.com/github/anamkamaal/Image_to-_pencil_sketch/blob/main/pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab.patches import cv2_imshow

# %%
import cv2

# %%
img = cv2.imread("/content/sample_data/rohit.png")

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=950x1188 at 0x7F85C3A3BD50>

# %%
img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(img_gray)
# Out:
# <PIL.Image.Image image mode=L size=950x1188 at 0x7F85C39C97D0>

# %%
img_invert = cv2.bitwise_not(img_gray)

# %%
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=950x1188 at 0x7F85C39CD610>

# %%
img_smoothing = cv2.GaussianBlur(img_invert, (21, 21),sigmaX=0, sigmaY=0)

cv2_imshow(img_smoothing)
# Out:
# <PIL.Image.Image image mode=L size=950x1188 at 0x7F85C39CDD90>

# %%
def dodgeV2(x, y):
    return cv2.divide(x, 255 - y, scale=256)

# %%
final_img = dodgeV2(img_gray, img_smoothing)

cv2_imshow(final_img)
# Out:
# <PIL.Image.Image image mode=L size=950x1188 at 0x7F85C39CD590>
